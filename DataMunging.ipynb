# %%
import os
from glob import glob
import pandas as pd
os.chdir("/Users/pavannaik/Desktop/BDV")

# %%
extension = 'csv'
all_filenames = [i for i in glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("combined_csv.csv")

# %%
df.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0  2018        2      4             1            7  2018-04-01
# 1  2018        2      4             1            7  2018-04-01
# 2  2018        2      4             1            7  2018-04-01
# 3  2018        2      4             1            7  2018-04-01
# 4  2018        2      4             1            7  2018-04-01
#
#   OP_UNIQUE_CARRIER  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_CITY_NAME  ...  DIVERTED  \
# 0                F9              13487    MSP  Minneapolis, MN  ...       0.0
# 1                F9              11292    DEN       Denver, CO  ...       0.0
# 2                F9              13485    MSN      Madison, WI  ...       0.0
# 3                F9              13204    MCO      Orlando, FL  ...       0.0
# 4                F9              13485    MSN      Madison, WI  ...       0.0
#
#   AIR_TIME FLIGHTS  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# ...

# %%
df.shape
# Out:
# (7275174, 28)

# %%
American = df[df.OP_UNIQUE_CARRIER=='AA']

# %%
American.head()
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 322758  2018        2      4             9            1  2018-04-09
# 322759  2018        2      4            10            2  2018-04-10
# 322760  2018        2      4            11            3  2018-04-11
# 322761  2018        2      4            12            4  2018-04-12
# 322762  2018        2      4            13            5  2018-04-13
#
#        OP_UNIQUE_CARRIER  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_CITY_NAME  ...  \
# 322758                AA              14107    PHX      Phoenix, AZ  ...
# 322759                AA              14107    PHX      Phoenix, AZ  ...
# 322760                AA              14107    PHX      Phoenix, AZ  ...
# 322761                AA              14107    PHX      Phoenix, AZ  ...
# 322762                AA              14107    PHX      Phoenix, AZ  ...
#
#         DIVERTED AIR_TIME FLIGHTS  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
American.shape
# Out:
# (922444, 28)

# %%
Delta = df[df.OP_UNIQUE_CARRIER=='DL']

# %%
Delta.head()
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 419129  2018        2      4             1            7  2018-04-01
# 419130  2018        2      4             1            7  2018-04-01
# 419131  2018        2      4             1            7  2018-04-01
# 419132  2018        2      4             1            7  2018-04-01
# 419133  2018        2      4             1            7  2018-04-01
#
#        OP_UNIQUE_CARRIER  ORIGIN_AIRPORT_ID ORIGIN    ORIGIN_CITY_NAME  ...  \
# 419129                DL              12892    LAX     Los Angeles, CA  ...
# 419130                DL              12892    LAX     Los Angeles, CA  ...
# 419131                DL              12892    LAX     Los Angeles, CA  ...
# 419132                DL              14869    SLC  Salt Lake City, UT  ...
# 419133                DL              11292    DEN          Denver, CO  ...
#
#         DIVERTED AIR_TIME FLIGHTS  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
Delta.shape
# Out:
# (961994, 28)

# %%
ExpressJet = df[df.OP_UNIQUE_CARRIER=='EV']

# %%
ExpressJet.head()
# Out:
#       YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 8385  2018        2      4             1            7  2018-04-01
# 8386  2018        2      4             2            1  2018-04-02
# 8387  2018        2      4             3            2  2018-04-03
# 8388  2018        2      4             4            3  2018-04-04
# 8389  2018        2      4             5            4  2018-04-05
#
#      OP_UNIQUE_CARRIER  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_CITY_NAME  ...  \
# 8385                EV              10781    BTR  Baton Rouge, LA  ...
# 8386                EV              10781    BTR  Baton Rouge, LA  ...
# 8387                EV              11057    CLT    Charlotte, NC  ...
# 8388                EV              11057    CLT    Charlotte, NC  ...
# 8389                EV              11057    CLT    Charlotte, NC  ...
#
#       DIVERTED AIR_TIME FLIGHTS  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
ExpressJet.shape
# Out:
# (207794, 28)

# %%
Southwest = df[df.OP_UNIQUE_CARRIER=='WN']

# %%
Southwest.head()
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 165696  2018        2      4             2            1  2018-04-02
# 165697  2018        2      4             2            1  2018-04-02
# 165698  2018        2      4             2            1  2018-04-02
# 165699  2018        2      4             2            1  2018-04-02
# 165700  2018        2      4             2            1  2018-04-02
#
#        OP_UNIQUE_CARRIER  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_CITY_NAME  ...  \
# 165696                WN              13232    MDW      Chicago, IL  ...
# 165697                WN              13232    MDW      Chicago, IL  ...
# 165698                WN              13232    MDW      Chicago, IL  ...
# 165699                WN              13232    MDW      Chicago, IL  ...
# 165700                WN              13232    MDW      Chicago, IL  ...
#
#         DIVERTED AIR_TIME FLIGHTS  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
Southwest.shape
# Out:
# (1369795, 28)

# %%
ADES = pd.concat([American, Delta, ExpressJet, Southwest])

# %%
ADES.head()
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 322758  2018        2      4             9            1  2018-04-09
# 322759  2018        2      4            10            2  2018-04-10
# 322760  2018        2      4            11            3  2018-04-11
# 322761  2018        2      4            12            4  2018-04-12
# 322762  2018        2      4            13            5  2018-04-13
#
#        OP_UNIQUE_CARRIER  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_CITY_NAME  ...  \
# 322758                AA              14107    PHX      Phoenix, AZ  ...
# 322759                AA              14107    PHX      Phoenix, AZ  ...
# 322760                AA              14107    PHX      Phoenix, AZ  ...
# 322761                AA              14107    PHX      Phoenix, AZ  ...
# 322762                AA              14107    PHX      Phoenix, AZ  ...
#
#         DIVERTED AIR_TIME FLIGHTS  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
ADES.shape
# Out:
# (3462027, 28)

# %%
ADES.to_csv(r'/Users/pavannaik/Desktop/BDV/ADES.csv', index = None, header=True)
